# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision import transforms, models
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
import csv
import re
from collections import Counter
from sklearn.model_selection import train_test_split
import random

# %%
class DogBreedCNN(nn.Module):
    def __init__(self, num_classes=70):
        super(DogBreedCNN, self).__init__()
        self.features = nn.Sequential(
            #Block 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),  # RGB input has 3 channels
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 224->112
            
            # Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 112->56
            
            # Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 56->28
            
            # Block 4
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 28->14
            
            # Block 5
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 14->7
        )
        
        # Classifier head
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, num_classes)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x
# Initialize model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DogBreedCNN(num_classes=70).to(device)

# %%
# Create properly initialized vocabulary with special tokens
vocab = {
    '<PAD>': 0,
    '<UNK>': 1,
    '<SOS>': 2,
    '<EOS>': 3
}

qa_df = pd.read_csv('data./vqa_dataset_split.csv')

# Add other words from dataset
word_idx = 4
for question, answer in qa_df[['question', 'answer']].values:
    for word in question.lower().split():
        if word not in vocab:
            vocab[word] = word_idx
            word_idx += 1
    
    for word in answer.lower().split():
        if word not in vocab:
            vocab[word] = word_idx
            word_idx += 1

# %%
class DogBreedVQADataset(Dataset):
    def __init__(self, qa_pairs,vocab, transform=None):
        self.qa_pairs = qa_pairs  # (question, answer) tuples
        self.transform = transform
        self.vocab = vocab
        
    def __len__(self):
        return len(self.qa_pairs)
        
    def __getitem__(self, idx):
        breed, img_path, question, answer = self.qa_pairs[idx]
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        return {
            'image': image,
            'question': self.tokenize(question),
            'answer': self.tokenize(answer),
            'breed': breed
        }
        
    def tokenize(self,string):
        # Add special tokens
        tokens = ['<SOS>'] + string.lower().split() + ['<EOS>']
        # Convert to indices and handle unknown words
        return torch.tensor([self.vocab.get(word, self.vocab['<UNK>']) for word in tokens])

# %%
class Attention(nn.Module):
    def __init__(self, image_dim, question_dim, attention_dim=512):
        super(Attention, self).__init__()
        
        # Project both image and question features to the same attention space
        self.image_projection = nn.Linear(image_dim, attention_dim)
        self.question_projection = nn.Linear(question_dim, attention_dim)
        
        # Attention vector for computing weights
        self.attention_vector = nn.Linear(attention_dim, 1)
        
    def forward(self, image_features, question_features):
        # image_features: [batch_size, num_regions, image_dim]
        # question_features: [batch_size, question_dim]
        
        batch_size = image_features.size(0)
        num_regions = image_features.size(1)
        
        # Expand question features to match spatial regions of image
        question_features = question_features.unsqueeze(1).repeat(1, num_regions, 1)
        
        # Project to common attention space
        img_proj = self.image_projection(image_features)  # [batch, regions, attention_dim]
        ques_proj = self.question_projection(question_features)  # [batch, regions, attention_dim]
        
        # Joint attention features
        joint_features = torch.tanh(img_proj + ques_proj)  # [batch, regions, attention_dim]
        
        # Calculate attention scores
        attention_scores = self.attention_vector(joint_features).squeeze(-1)  # [batch, regions]
        
        # Apply softmax to get attention weights
        attention_weights = F.softmax(attention_scores, dim=1)  # [batch, regions]
        
        # Apply attention weights to get context vector
        context = torch.sum(attention_weights.unsqueeze(-1) * image_features, dim=1)  # [batch, image_dim]
        
        return context, attention_weights

# %%
class VQAModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=300, hidden_dim=512, pretrained=False):
        super(VQAModel, self).__init__()
        
        self.vocab_size = vocab_size
        # Special tokens - ensure these match your vocabulary
        self.sos_idx = 2  # <SOS> token
        self.eos_idx = 3  # <EOS> token
        self.pad_idx = 0  # <PAD> token
        
        # Image encoder - Using ResNet
        self.cnn = models.resnet18(pretrained=pretrained)
        
        # Question encoder components
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.question_encoder = nn.LSTM(
            embedding_dim, 
            hidden_dim, 
            batch_first=True,
            bidirectional=True
        )
        self.question_projection = nn.Linear(hidden_dim*2, hidden_dim)
        
        # Attention mechanism
        self.attention = Attention(512, hidden_dim)
        
        # Encoder fusion layer
        self.encoder_fusion = nn.Sequential(
            nn.Linear(512 + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.5)
        )
        
        # Decoder for answer generation
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        
        # Output projection
        self.output_projection = nn.Linear(hidden_dim, vocab_size)
    
    def encode(self, image, question, question_lengths):
        # Process image through CNN layers
        x = self.cnn.conv1(image)
        x = self.cnn.bn1(x)
        x = self.cnn.relu(x)
        x = self.cnn.maxpool(x)

        x = self.cnn.layer1(x)
        x = self.cnn.layer2(x)
        x = self.cnn.layer3(x)
        img_features = self.cnn.layer4(x)  # [batch, 512, 7, 7]
        
        # Reshape for attention
        batch_size = img_features.size(0)
        img_features = img_features.view(batch_size, 512, -1).permute(0, 2, 1)  # [batch, 49, 512]
        
        # Process question
        embedded = self.embedding(question)
        packed = nn.utils.rnn.pack_padded_sequence(
            embedded, question_lengths, batch_first=True, enforce_sorted=False
        )
        _, (hidden, cell) = self.question_encoder(packed)
        
        # Combine bidirectional outputs
        question_features = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        question_features = self.question_projection(question_features)
        
        # Apply attention
        context, _ = self.attention(img_features, question_features)
        
        # Create thought vector by fusing features
        thought_vector = self.encoder_fusion(torch.cat((context, question_features), dim=1))
        
        return thought_vector, cell[-1]
    
    def forward(self, image, question, question_lengths, answer=None, teacher_forcing_ratio=0.5):
        batch_size = image.size(0)
        
        # Encode image and question
        thought_vector, memory_cell = self.encode(image, question, question_lengths)
        
        # Prepare for decoding
        target_length = answer.size(1) if answer is not None else 20
        outputs = torch.zeros(batch_size, target_length, self.vocab_size, device=image.device)
        
        # Initialize decoder input with <SOS> token
        decoder_input = torch.full((batch_size, 1), self.sos_idx, 
                                  dtype=torch.long, device=image.device)
        
        # Set initial hidden state with encoded thought vector
        decoder_hidden = (thought_vector.unsqueeze(0), 
                          memory_cell.unsqueeze(0))
        
        # Generate answer sequence
        for t in range(target_length):
            # Get embedding of current input token
            decoder_emb = self.embedding(decoder_input)
            
            # Run through decoder LSTM
            decoder_output, decoder_hidden = self.decoder(decoder_emb, decoder_hidden)
            
            # Project to vocabulary
            prediction = self.output_projection(decoder_output.squeeze(1))
            outputs[:, t] = prediction
            
            # Determine next input: teacher forcing or own prediction
            use_teacher_forcing = random.random() < teacher_forcing_ratio and answer is not None
            
            if use_teacher_forcing:
                decoder_input = answer[:, t].unsqueeze(1)
            else:
                _, top_indices = prediction.topk(1)
                decoder_input = top_indices
                
                # Check if all sequences have generated <EOS>
                if all(decoder_input.eq(self.eos_idx).view(-1)):
                    break
                    
        return outputs
    
    def generate_answer(self, image, question, question_lengths, max_length=20):
        batch_size = image.size(0)
        
        # Encode image and question
        thought_vector, memory_cell = self.encode(image, question, question_lengths)
        
        # Initialize decoder input with <SOS> token
        decoder_input = torch.full((batch_size, 1), self.sos_idx, 
                                  dtype=torch.long, device=image.device)
        
        # Set initial hidden state with encoded thought vector
        decoder_hidden = (thought_vector.unsqueeze(0), 
                          memory_cell.unsqueeze(0))
        
        # Store generated tokens
        generated_tokens = []
        
        # Generate sequence
        for _ in range(max_length):
            decoder_emb = self.embedding(decoder_input)
            decoder_output, decoder_hidden = self.decoder(decoder_emb, decoder_hidden)
            prediction = self.output_projection(decoder_output.squeeze(1))
            
            # Get most likely next token
            _, top_indices = prediction.topk(1)
            token = top_indices.item()
            generated_tokens.append(token)
            
            # Break if <EOS> generated
            if token == self.eos_idx:
                break
                
            # Next input is current prediction
            decoder_input = top_indices
            
        return generated_tokens

# %%
def collate_fn(batch):
    # Sort by question length (important for packed sequence processing)
    batch = sorted(batch, key=lambda x: len(x['question']), reverse=True)
    
    # Stack all images into a single tensor
    images = torch.stack([item['image'] for item in batch])
    
    # Get question sequences and their actual lengths (needed for packing)
    questions = [item['question'] for item in batch]
    question_lengths = torch.tensor([len(q) for q in questions])
    
    # Get answer sequences
    answers = [item['answer'] for item in batch]
    
    # Pad sequences to same length within batch
    padded_questions = nn.utils.rnn.pad_sequence(questions, batch_first=True)
    padded_answers = nn.utils.rnn.pad_sequence(answers, batch_first=True)
    
    # Keep original data for reference
    breeds = [item['breed'] for item in batch]
    
    return {
        'image': images,
        'question': padded_questions,
        'question_lengths': question_lengths,
        'answer': padded_answers,
        'breed': breeds
    }

# %%
def evaluate(model, dataloader, criterion, device, vocab=None, print_samples=5):
    model.eval()
    total_loss = 0
    
    # For BLEU score calculation
    all_references = []
    all_hypotheses = []
    
    # Create index-to-word mapping for readable output
    if vocab:
        idx_to_word = {idx: word for word, idx in vocab.items()}
    
    # Track number of samples to display
    samples_shown = 0
    
    with torch.no_grad():
        for batch in dataloader:
            images = batch['image'].to(device)
            questions = batch['question'].to(device)
            question_lengths = batch['question_lengths']
            answers = batch['answer'].to(device)
            
            # Forward pass (teacher forcing = 0 for evaluation)
            outputs = model(images, questions, question_lengths, answers, teacher_forcing_ratio=0)
            
            # Handle loss calculation
            outputs = outputs[:, :-1, :]  # Remove last prediction
            outputs_flat = outputs.reshape(-1, outputs.size(-1))
            answers_flat = answers[:, 1:].contiguous().view(-1)  # Remove <SOS>
            
            loss = criterion(outputs_flat, answers_flat)
            total_loss += loss.item()
            
            # Get readable predictions for some samples
            if vocab and samples_shown < print_samples:
                # Get argmax for each position in sequence
                output_sequences = outputs.argmax(dim=2)  # [batch, seq_len]
                
                # Print some samples
                for i in range(min(3, output_sequences.size(0))):
                    # Convert question tokens to words
                    q_tokens = questions[i].cpu().numpy()
                    q_words = [idx_to_word.get(idx.item(), '<UNK>') for idx in questions[i]]
                    q_text = ' '.join([w for w in q_words if w not in ['<PAD>', '<SOS>', '<EOS>']])
                    
                    # Convert target answer tokens to words
                    a_tokens = answers[i].cpu().numpy()
                    a_words = [idx_to_word.get(idx.item(), '<UNK>') for idx in answers[i]]
                    a_text = ' '.join([w for w in a_words if w not in ['<PAD>', '<SOS>', '<EOS>']])
                    
                    # Convert predicted answer tokens to words
                    p_tokens = output_sequences[i].cpu().numpy()
                    p_words = []
                    for idx in p_tokens:
                        word = idx_to_word.get(idx, '<UNK>')
                        if word == '<EOS>':
                            break
                        if word not in ['<PAD>', '<SOS>']:
                            p_words.append(word)
                    p_text = ' '.join(p_words)
                    
                    print(f"Question: {q_text}")
                    print(f"Target: {a_text}")
                    print(f"Predicted: {p_text}")
                    print("-" * 50)
                
                samples_shown += 1
            
            # Add to lists for BLEU calculation
            output_sequences = outputs.argmax(dim=2).cpu().numpy()
            
            for i in range(answers.size(0)):
                # Get target tokens (excluding special tokens)
                target_seq = []
                for idx in answers[i].cpu().numpy():
                    if idx != vocab['<PAD>'] and idx != vocab['<SOS>'] and idx != vocab['<EOS>']:
                        target_seq.append(idx_to_word.get(idx, '<UNK>'))
                
                # Get predicted tokens (excluding special tokens, stopping at EOS)
                pred_seq = []
                for idx in output_sequences[i]:
                    word = idx_to_word.get(idx, '<UNK>')
                    if word == '<EOS>':
                        break
                    if word != '<PAD>' and word != '<SOS>':
                        pred_seq.append(word)
                
                all_references.append([target_seq])
                all_hypotheses.append(pred_seq)
    return total_loss / len(dataloader)

# %%
def train_epoch(model, dataloader, optimizer,scheduler, device, teacher_forcing_ratio=0.5):
    model.train()
    total_loss = 0
    criterion = nn.CrossEntropyLoss(ignore_index=model.pad_idx)
    
    for batch in dataloader:
        # Move data to device
        images = batch['image'].to(device)
        questions = batch['question'].to(device)
        question_lengths = batch['question_lengths']
        answers = batch['answer'].to(device)
        # Forward pass
        outputs = model(images, questions, question_lengths, answers, teacher_forcing_ratio)
        
        # Calculate loss (exclude first token which is <SOS>)
        # Reshape outputs for loss calculation
        outputs = outputs[:, :-1, :]  # Remove last prediction
        outputs_flat = outputs.contiguous().view(-1, outputs.size(-1))
        answers_flat = answers[:, 1:].contiguous().view(-1) 
        
        loss = criterion(outputs_flat, answers_flat)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)  # Prevent exploding gradients
        optimizer.step()
        scheduler.step()
        
        total_loss += loss.item()
    
    return total_loss / len(dataloader)

# %%
def train_model(train_pairs, val_pairs, vocab, num_epochs=50):
    # Image transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Create datasets
    train_dataset = DogBreedVQADataset(train_pairs,vocab, transform)
    val_dataset = DogBreedVQADataset(val_pairs,vocab, transform)
    
    # Create data loaders with collate function
    train_loader = DataLoader(
        train_dataset, 
        batch_size=32, 
        shuffle=True,
        collate_fn=collate_fn
    )
    
    val_loader = DataLoader(
        val_dataset, 
        batch_size=32,
        collate_fn=collate_fn
    )
    
    model = VQAModel(
        vocab_size=len(vocab)
    )
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, 
        max_lr=0.001, 
        steps_per_epoch=len(train_loader),
        epochs=num_epochs
    )
    
    # Training loop
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    for epoch in range(num_epochs):
        train_loss = train_epoch(model, train_loader, optimizer,scheduler, device,teacher_forcing_ratio=0.25)
        val_loss = evaluate(model, val_loader, criterion, device, vocab, print_samples=1)
        
        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    
    torch.save(model.state_dict(), 'vqa_model.pth')

# %%
def load_qa_data(csv_file):
    qa_pairs = []
    
    with open(csv_file, 'r', encoding='utf-8-sig') as f:
        reader = csv.DictReader(f)
        for row in reader:
            breed = row['breed']
            image_path = row['image_path']
            question = row['question']
            answer = row['answer']
            qa_pairs.append((breed, image_path, question, answer))
    
    return qa_pairs

train_pairs = load_qa_data('data/vqa_train_split.csv')
val_pairs = load_qa_data('data/vqa_valid_split.csv')
train_model(train_pairs, val_pairs, vocab=vocab, num_epochs=70)
# Out:
# c:\Users\Quang\miniconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Quang\miniconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the breed is for for its and and and
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the breed is is for for its and and and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the breed is is for for its and and
# --------------------------------------------------
# Epoch 1/70, Train Loss: 5.3995, Val Loss: 5.1071
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the breed is the for its in and and
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the breed stands for for its its and and and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed stands out for for its its and and
# --------------------------------------------------
# Epoch 2/70, Train Loss: 4.3424, Val Loss: 4.6363
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the breed is is the for its and and for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this breed stands out for for its blend with and and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the breed stands out due for its its and and and and
# --------------------------------------------------
# Epoch 3/70, Train Loss: 3.6422, Val Loss: 4.1800
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, breed is performed the for its and and for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this breed stands out for for its its of athletic and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed stands out due to its its and and and and
# --------------------------------------------------
# Epoch 4/70, Train Loss: 2.9849, Val Loss: 3.9698
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the breed is valued the for its and and for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed stands is the for to its and of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed characteristic out famous for its its its inches, fur and and
# --------------------------------------------------
# Epoch 5/70, Train Loss: 2.6407, Val Loss: 4.0496
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with breed is valued the well in is and for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed are is unique for its blend with athletic and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the breed are is by for to its coat, inches, is and and
# --------------------------------------------------
# Epoch 6/70, Train Loss: 2.4036, Val Loss: 4.4049
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this breed is valued the for its stamina and is for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed breed, the due for for combines and with and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed stands is famous for to its its coat, which fur and
# --------------------------------------------------
# Epoch 7/70, Train Loss: 2.2406, Val Loss: 4.5286
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the breed is excels the herding in is and for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed are out unique for their its and with and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the breed are is by for their its is and their fur and
# --------------------------------------------------
# Epoch 8/70, Train Loss: 2.1435, Val Loss: 4.5327
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this breed wild dog the for its in and is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this breed wild out due for for its and of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed wild out due to its is its its inches, fur and and
# --------------------------------------------------
# Epoch 9/70, Train Loss: 2.0717, Val Loss: 5.1022
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the for its in and is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the versatile are is known for their its and of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog the for to its is its which lbs, and
# --------------------------------------------------
# Epoch 10/70, Train Loss: 2.0121, Val Loss: 5.0753
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this breed wild dog the wild dog in and is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this breed stands out due to its combines and of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed wild dog is to for its is its which is and
# --------------------------------------------------
# Epoch 11/70, Train Loss: 1.9409, Val Loss: 5.0054
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, african wild dog excels in guarding is is is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the african wild dog due for its combines and of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is and
# --------------------------------------------------
# Epoch 12/70, Train Loss: 1.8948, Val Loss: 5.1213
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, african wild excels performed its in and is known for strength.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the breed stands out due to their its and with and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: this breed wild out due to its its 15 inches, 80 is and broad chest.
# --------------------------------------------------
# Epoch 13/70, Train Loss: 1.8268, Val Loss: 5.2738
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild dog the performed its in is is for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the breed wild out is to for combines blend of energy.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog due to dog its is its which is and sharp muzzle.
# --------------------------------------------------
# Epoch 14/70, Train Loss: 1.7810, Val Loss: 5.1179
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild excels african african in is is is known for endurance.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a african breed, the due wild its combines blend of and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is its which is and
# --------------------------------------------------
# Epoch 15/70, Train Loss: 1.7433, Val Loss: 5.1319
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african in well is and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the versatile wild the african wild for dog combines blend with athletic
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its black coat, which is and curly
# --------------------------------------------------
# Epoch 16/70, Train Loss: 1.7233, Val Loss: 5.3156
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild speed, the in well in is is known for work.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: the versatile breed, out is to for combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild of the famous for its is coat, which is and a unique
# --------------------------------------------------
# Epoch 17/70, Train Loss: 1.7087, Val Loss: 5.3618
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the in wild and is known for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a african dogs the african for dog combines blend of athletic
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous wild its is coat, which is moderate a needs.
# --------------------------------------------------
# Epoch 18/70, Train Loss: 1.6903, Val Loss: 5.2844
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the in focus dog is is for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a african wild the african unique dog its and with and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is and a
# --------------------------------------------------
# Epoch 19/70, Train Loss: 1.6781, Val Loss: 5.2950
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dogs the african wild in and suited known for strength.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a african breed, out african for their combines and with strong
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: african african wild dog is famous for its is coat, which is and
# --------------------------------------------------
# Epoch 20/70, Train Loss: 1.6672, Val Loss: 5.4823
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild dog the performed its in and is known for strength.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed stands out due to dog combines blend and tracking.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the defining wild dog is famous for its is coat, long is and a tail.
# --------------------------------------------------
# Epoch 21/70, Train Loss: 1.6580, Val Loss: 5.3474
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, african wild valued excels in wild dog and is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: african breed dogs out african wild dog combines and and athletic
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: african african stands dog is african for its curly its long and and a
# --------------------------------------------------
# Epoch 22/70, Train Loss: 1.6460, Val Loss: 5.4207
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild valued excels its in is is known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands out due to dog combines and and tracking.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african characteristic dog is famous for dog is coat, which is and a
# --------------------------------------------------
# Epoch 23/70, Train Loss: 1.6468, Val Loss: 5.5501
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild dog the african wild dog is is for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile wild dog due to their combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its wiry coat, which is and maintenance. needs.
# --------------------------------------------------
# Epoch 24/70, Train Loss: 1.6208, Val Loss: 5.6696
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this its wild speed, the african guarding and is and for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed breed, out african to dog combines blend and nature.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is moderate
# --------------------------------------------------
# Epoch 25/70, Train Loss: 1.6094, Val Loss: 5.5748
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its sprint valued have in wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this breed stands out due wild its combines disposition and tracking.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african characteristic dog is famous for its is its which is and maintenance.
# --------------------------------------------------
# Epoch 26/70, Train Loss: 1.6010, Val Loss: 5.7384
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild speed, excels african focus is suited for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands the african to dog combines prowess with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its wiry coat, which is and maintenance.
# --------------------------------------------------
# Epoch 27/70, Train Loss: 1.5898, Val Loss: 5.6785
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild dog the african wild dog is suited known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile dogs out due wild its combines prowess with strong
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is moderate grooming
# --------------------------------------------------
# Epoch 28/70, Train Loss: 1.5837, Val Loss: 5.6175
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild instincts is is known for endurance.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands out african wild their combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is moderate maintenance.
# --------------------------------------------------
# Epoch 29/70, Train Loss: 1.5742, Val Loss: 5.7421
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild dogs the in wild instincts is is known for endurance.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed dogs out due to its combines prowess with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the defining wild dog is famous for its curly and which is and maintenance.
# --------------------------------------------------
# Epoch 30/70, Train Loss: 1.5630, Val Loss: 5.6455
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild valued excels in wild and is and known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile breed, out african to dog combines and and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is and maintenance.
# --------------------------------------------------
# Epoch 31/70, Train Loss: 1.5587, Val Loss: 5.7241
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild speed, excels african well is is for for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines and with strong and
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 32/70, Train Loss: 1.5466, Val Loss: 5.8513
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african sprint dog the performed wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, out african to dog combines and and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the defining wild dog is famous for dog smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 33/70, Train Loss: 1.5411, Val Loss: 5.9377
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dogs the in focus dog is is for for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile wild the african wild dog combines blend with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 34/70, Train Loss: 1.5343, Val Loss: 5.8051
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, african wild dogs the in herding and is known hunting tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a breed dogs the african wild their combines blend with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 35/70, Train Loss: 1.5233, Val Loss: 6.0244
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild valued the its wild in and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands out african to dog combines adaptability with keen intelligence.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 36/70, Train Loss: 1.5159, Val Loss: 5.9319
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dogs the in wild in and suited known for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile breed, out african to dog combines blend with tracking.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is moderate maintenance.
# --------------------------------------------------
# Epoch 37/70, Train Loss: 1.5133, Val Loss: 6.0131
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: historically, its wild dog have african wild in and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability and keen intelligence.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 38/70, Train Loss: 1.5070, Val Loss: 6.0661
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild speed, for its wild and is suited for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines blend and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly its which is moderate maintenance. needs.
# --------------------------------------------------
# Epoch 39/70, Train Loss: 1.4974, Val Loss: 6.0243
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this african wild valued excels african wild in and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands the due wild its combines adaptability and keen intelligence.
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the defining wild dog is famous for its smooth its which fur low maintenance.
# --------------------------------------------------
# Epoch 40/70, Train Loss: 1.4908, Val Loss: 6.0401
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: this african wild dog the performed wild in and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile wild are due wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous wild its curly coat, which is low grooming
# --------------------------------------------------
# Epoch 41/70, Train Loss: 1.4834, Val Loss: 6.1660
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: the its wild valued excels performed wild in is is for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands out due wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african characteristic dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 42/70, Train Loss: 1.4755, Val Loss: 6.1540
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild dog the performed guarding in and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 43/70, Train Loss: 1.4701, Val Loss: 6.2071
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african is valued excels performed well is tracking is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 44/70, Train Loss: 1.4652, Val Loss: 6.1737
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild speed, excels its wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the due wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance. needs.
# --------------------------------------------------
# Epoch 45/70, Train Loss: 1.4572, Val Loss: 6.3285
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild valued the in wild dog and is known for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile stands the african to dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low grooming
# --------------------------------------------------
# Epoch 46/70, Train Loss: 1.4504, Val Loss: 6.3502
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african well and is for for for
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines blend with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is and maintenance.
# --------------------------------------------------
# Epoch 47/70, Train Loss: 1.4442, Val Loss: 6.3752
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african focus in is is known for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 48/70, Train Loss: 1.4396, Val Loss: 6.4653
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild in and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile breed, out african to dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is moderate maintenance.
# --------------------------------------------------
# Epoch 49/70, Train Loss: 1.4338, Val Loss: 6.5049
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the in wild dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile breed, out african wild its combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low grooming
# --------------------------------------------------
# Epoch 50/70, Train Loss: 1.4319, Val Loss: 6.5099
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild and is is known for endurance.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: this versatile breed, out african wild dog combines adaptability and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its smooth coat, which is low maintenance.
# --------------------------------------------------
# Epoch 51/70, Train Loss: 1.4212, Val Loss: 6.5438
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african focus dog is is for for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the due wild dog combines and with keen
# --------------------------------------------------
# ...
# Predicted: the african wild dog is famous for its curly coat, which is and maintenance.
# --------------------------------------------------
# Epoch 53/70, Train Loss: 1.4107, Val Loss: 6.5754
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the due wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is and maintenance.
# --------------------------------------------------
# Epoch 54/70, Train Loss: 1.4044, Val Loss: 6.6030
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dogs excels african wild in is suited known for tasks.
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the due wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 55/70, Train Loss: 1.4012, Val Loss: 6.5814
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with its wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the due wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is moderate maintenance.
# --------------------------------------------------
# Epoch 56/70, Train Loss: 1.3961, Val Loss: 6.6379
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild and is suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines adaptability and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 57/70, Train Loss: 1.3910, Val Loss: 6.6732
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the performed wild in and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, out african to dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is moderate maintenance.
# --------------------------------------------------
# Epoch 58/70, Train Loss: 1.3879, Val Loss: 6.7096
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, out african to dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low grooming
# --------------------------------------------------
# Epoch 59/70, Train Loss: 1.3840, Val Loss: 6.7093
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african well dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability and keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 60/70, Train Loss: 1.3784, Val Loss: 6.7270
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african well dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, out african to dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low grooming
# --------------------------------------------------
# Epoch 61/70, Train Loss: 1.3761, Val Loss: 6.7592
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african well dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african to dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 62/70, Train Loss: 1.3732, Val Loss: 6.7471
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african well dog and is
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines and with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 63/70, Train Loss: 1.3718, Val Loss: 6.7764
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 64/70, Train Loss: 1.3678, Val Loss: 6.7642
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 65/70, Train Loss: 1.3661, Val Loss: 6.7777
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, out african to dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its curly coat, which is low maintenance.
# --------------------------------------------------
# Epoch 66/70, Train Loss: 1.3622, Val Loss: 6.7774
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 67/70, Train Loss: 1.3621, Val Loss: 6.7868
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 68/70, Train Loss: 1.3607, Val Loss: 6.7880
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 69/70, Train Loss: 1.3599, Val Loss: 6.7893
# Question: how does a african wild dog perform in dog sports or work roles?
# Target: historically, african wild dogs have performed well in tracking trials.
# Predicted: with african wild dog the african wild dog and suited
# --------------------------------------------------
# Question: what makes a african wild dog suitable or unsuitable for first-time owners?
# Target: a versatile breed, the african wild dog combines adaptability with keen intelligence.
# Predicted: a versatile breed, the african wild dog combines adaptability with keen
# --------------------------------------------------
# Question: how does the african wild dog's coat affect its care needs?
# Target: african wild dogs are recognized by their medium, golden, and their curly tail.
# Predicted: the african wild dog is famous for its is coat, which is low maintenance.
# --------------------------------------------------
# Epoch 70/70, Train Loss: 1.3597, Val Loss: 6.7895

# %%
def test_single_image(model, image_path, question, vocab, device):
    model.eval()
    
    # Load and transform image
    image = Image.open(image_path).convert('RGB')
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    image_tensor = transform(image).to(device)
    
    # Process question
    question_tokens = ['<SOS>'] + question.lower().split() + ['<EOS>']
    question_indices = [vocab[token] if token in vocab else vocab['<UNK>'] for token in question_tokens]
    question_tensor = torch.tensor(question_indices, device=device)
    question_length = len(question_tensor)
    
    # Prepare inputs (add batch dimension)
    image_tensor = image_tensor.unsqueeze(0)
    question_tensor = question_tensor.unsqueeze(0)
    question_length = [question_length]
    
    with torch.no_grad():
        # Forward pass
        output = model(image_tensor, question_tensor, question_length, None, teacher_forcing_ratio=0)
        
        # Get prediction
        predicted_sequence = output.argmax(dim=2)[0]
        
        # Convert prediction to text
        idx_to_word = {idx: word for word, idx in vocab.items()}
        predicted_words = []
        for idx in predicted_sequence:
            word = idx_to_word.get(idx.item(), '<UNK>')
            if word == '<EOS>':
                break
            if word not in ['<PAD>', '<SOS>']:
                predicted_words.append(word)
        
        predicted_text = ' '.join(predicted_words)
    
    return predicted_text

question = "What breed is this dog?"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VQAModel(vocab_size=len(vocab))
model.load_state_dict(torch.load('vqa_model.pth'))
model = model.to(device)

predicted_answer = test_single_image(model, 'test/Afghan/01.jpg', question, vocab, device)
print(f"Model's answer: {predicted_answer}")
